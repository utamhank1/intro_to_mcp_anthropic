# %%
# Install dependencies.
# %pip install "anthropic[vertex]" python-dotenv
# Out:
# /Users/ujjwaltamhankar/Desktop/Coalesce/Claude_Sandbox/intro_to_mcp_anthropic/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load environment variables from .env file.
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create a Vertex AI client.
import os
from anthropic import AnthropicVertex

client = AnthropicVertex(
    project_id=os.getenv("GCP_PROJECT_ID"),
    region=os.getenv("GCP_REGION"),
)
model = os.getenv("CLAUDE_MODEL")

# %%
def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages
    )
    return message.content[0].text

# %%
message.content[0].text
# Out:
# "I'd be happy to write a sentence, but could you give me a little more context? For example:\n\n- What **topic** should it be about?\n- What **style** or **tone** are you looking for?\n- Is this a continuation of something you're already writing?\n\nJust let me know and I'll help!"
