# %%
# Install dependencies.
# %pip install "anthropic[vertex]" python-dotenv
# Out:
# /Users/ujjwaltamhankar/Desktop/Coalesce/Claude_Sandbox/intro_to_mcp_anthropic/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load environment variables from .env file.
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create a Vertex AI client.
import os
from anthropic import AnthropicVertex

client = AnthropicVertex(
    project_id=os.getenv("GCP_PROJECT_ID"),
    region=os.getenv("GCP_REGION"),
)
model = os.getenv("CLAUDE_MODEL")

# %%
def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages
    )
    return message.content[0].text

# %%
# Initialize messages list
messages = []

# Add a user message
add_user_message(messages, "Your question here")

# Get the response from chat
response = chat(messages)
response
# Out:
# /Users/ujjwaltamhankar/Desktop/Coalesce/Claude_Sandbox/intro_to_mcp_anthropic/.venv/lib/python3.14/site-packages/google/auth/_default.py:113: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# "It looks like your message came through empty! 😊\n\nPlease go ahead and ask your question — I'm here to help with whatever you need!"

# %%
# Make a starting list of messages.
messages = []

# Add in the initial user question of "Define quantum computing in one sentence."
add_user_message(messages, "Define quantum computing in one sentence.")

# Pass the list of messages into 'chat' to get an answer.
answer = chat(messages)
answer

# Take the answer and add it as an assistant message into our list.
add_assistant_message(messages, answer)
messages

# Add in the user's follow-up question.
add_user_message(messages, "Write another sentence.")

# Call chat again with the list of messages.
answer = chat(messages)
answer
# Out:
# 'Unlike classical computers, which store information as binary bits (0s and 1s), quantum computers use quantum bits, or "qubits," which can exist in multiple states simultaneously, enabling them to perform many calculations at once.'

# %%
# Make an intial list of messages.
messages = []

# Run chatbot forever with a while loop.
while True:
    # Get and store user input.
    user_input = input("> ")
    print(">", user_input)

    # Add user input to the list of messages.
    # Call claude with the 'chat' function.
    # Add generated text to the list of messages.
    # Print the generated text. 
    add_user_message(messages, user_input)
    session = chat(messages)
    add_assistant_message(messages, session)
    print("-----")
    print("Claude:", session)
    print("-----")
# Out:
# > what is 1+1
# -----
# Claude: 1 + 1 = **2**
# -----
# > what if you add 1 to it?
# -----
# Claude: If you add 1 to **2**, you get:
#
# 2 + 1 = **3**
# -----
# > what if I add 3 to that?
# -----
# Claude: If you add 3 to **3**, you get:
#
# 3 + 3 = **6**
# -----
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[9], line 15
#      11     # Call claude with the 'chat' function.
#      12     # Add generated text to the list of messages.
#      13     # Print the generated text.
#      14     add_user_message(messages, user_input)
# ---> 15     session = chat(messages)
#      16     add_assistant_message(messages, session)
#      17     print("-----")
#      18     print("Claude:", session)
#
# Cell In[4], line 15, in chat(messages)
#      14 def chat(messages):
# ---> 15     message = client.messages.create(
#      16         model = model,
# ...
